# %% [markdown]
# # Doing retrieval on CD-35 2722 system observed on 2022-12-31.
# ---
# According to the notebook created by Natalie, and modified by Jiacheng.
#
# Created by Chenyang Ji in 2025.12.22.
